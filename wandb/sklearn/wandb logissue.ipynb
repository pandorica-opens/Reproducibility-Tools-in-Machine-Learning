# %% [markdown]
# # Issue

# %%
# %%capture output
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import wandb

wandb.init(project = 'issue', config={"gamma":0.1, "C":1.0, "test_size": 0.3, "seed": 0})

iris = datasets.load_iris()

X = iris.data[:, [2, 3]]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=wandb.config.test_size, random_state=wandb.config.seed)

sc = StandardScaler()
sc.fit(X_train)

X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

svm = SVC(kernel='rbf', random_state=wandb.config.seed, gamma=wandb.config.gamma, C=wandb.config.C)
svm.fit(X_train_std, y_train)

wandb.log({"Train Accuracy": svm.score(X_train_std, y_train), 
           "Test Accuracy": svm.score(X_test_std, y_test)})

def plot_data():
    from matplotlib.colors import ListedColormap
    import matplotlib.pyplot as plt

    markers = ('s', 'x', 'o')
    colors = ('red', 'blue', 'lightgreen')
    cmap = ListedColormap(colors[:len(np.unique(y_test))])
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
               c=cmap(idx), marker=markers[idx], label=cl)

    wandb.log({"Data": plt})
    
    wandb.log({"Same data": plt})

plot_data()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-70595add8937> in <module>
#      45     wandb.log({"Same data": plt})
#      46
# ---> 47 plot_data()
#
# <ipython-input-17-70595add8937> in plot_data()
#      43     wandb.log({"Data": plt})
#      44
# ---> 45     wandb.log({"Same data": plt})
#      46
#      47 plot_data()
#
# /anaconda3/lib/python3.7/site-packages/wandb/sdk/wandb_run.py in log(self, data, step, commit, sync)
#     807             commit = True
#     808         if commit:
# --> 809             self.history._row_add(data)
#     810         else:
#     811             self.history._row_update(data)
#
# /anaconda3/lib/python3.7/site-packages/wandb/sdk/wandb_history.py in _row_add(self, row)
#      42     def _row_add(self, row):
#      43         self._data.update(row)
# ---> 44         self._flush()
#      45         self._step += 1
#      46
#
# /anaconda3/lib/python3.7/site-packages/wandb/sdk/wandb_history.py in _flush(self)
#      57             self._data["_timestamp"] = int(self._data.get("_timestamp", time.time()))
#      58             if self._callback:
# ---> 59                 self._callback(row=self._data, step=self._step)
#      60             self._data = dict()
#      61
#
# /anaconda3/lib/python3.7/site-packages/wandb/sdk/wandb_run.py in _history_callback(self, row, step)
#     596             self._config_callback(data=self._config._as_dict())
#     597
# --> 598         self._backend.interface.publish_history(row, step)
#     599
#     600     def _console_callback(self, name, data):
#
# /anaconda3/lib/python3.7/site-packages/wandb/sdk/interface/interface.py in publish_history(self, data, step, run)
#     170     def publish_history(self, data, step=None, run=None):
#     171         run = run or self._run
# --> 172         data = data_types.history_dict_to_json(run, data, step=step)
#     173         history = wandb_internal_pb2.HistoryRecord()
#     174         for k, v in six.iteritems(data):
#
# /anaconda3/lib/python3.7/site-packages/wandb/data_types.py in history_dict_to_json(run, payload, step)
#    2491             payload[key] = history_dict_to_json(run, val, step=step)
#    2492         else:
# -> 2493             payload[key] = val_to_json(run, key, val, namespace=step)
#    2494
#    2495     return payload
#
# /anaconda3/lib/python3.7/site-packages/wandb/data_types.py in val_to_json(run, key, val, namespace)
#    2540         return data_frame_to_json(val, run, key, namespace)
#    2541     elif util.is_matplotlib_typename(typename) or util.is_plotly_typename(typename):
# -> 2542         val = Plotly.make_plot_media(val)
#    2543     elif isinstance(val, collections.Sequence) and all(
#    2544         isinstance(v, WBValue) for v in val
#
# /anaconda3/lib/python3.7/site-packages/wandb/data_types.py in make_plot_media(cls, val)
#    2046             if util.matplotlib_contains_images(val):
#    2047                 return Image(val)
# -> 2048             val = util.matplotlib_to_plotly(val)
#    2049         return cls(val)
#    2050
#
# /anaconda3/lib/python3.7/site-packages/wandb/util.py in matplotlib_to_plotly(obj)
#     383         required="plotly is required to log interactive plots, install with: pip install plotly or convert the plot to an image with `wandb.Image(plt)`",
#     384     )
# --> 385     return tools.mpl_to_plotly(obj)
#     386
#     387
#
# /anaconda3/lib/python3.7/site-packages/plotly/tools.py in mpl_to_plotly(fig, resize, strip_style, verbose)
#     110     if matplotlylib:
#     111         renderer = matplotlylib.PlotlyRenderer()
# --> 112         matplotlylib.Exporter(renderer).run(fig)
#     113         if resize:
#     114             renderer.resize()
#
# /anaconda3/lib/python3.7/site-packages/plotly/matplotlylib/mplexporter/exporter.py in run(self, fig)
#      49             import matplotlib.pyplot as plt
#      50             plt.close(fig)
# ---> 51         self.crawl_fig(fig)
#      52
#      53     @staticmethod
#
# /anaconda3/lib/python3.7/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_fig(self, fig)
#     114         """Crawl the figure and process all axes"""
#     115         with self.renderer.draw_figure(fig=fig,
# --> 116                                        props=utils.get_figure_properties(fig)):
#     117             for ax in fig.axes:
#     118                 self.crawl_ax(ax)
#
# /anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /anaconda3/lib/python3.7/site-packages/plotly/matplotlylib/mplexporter/renderers/base.py in draw_figure(self, fig, props)
#      43         self._current_fig = fig
#      44         self._fig_props = props
# ---> 45         self.open_figure(fig=fig, props=props)
#      46         yield
#      47         self.close_figure(fig=fig)
#
# /anaconda3/lib/python3.7/site-packages/plotly/matplotlylib/renderer.py in open_figure(self, fig, props)
#      88             hovermode="closest",
#      89         )
# ---> 90         self.mpl_x_bounds, self.mpl_y_bounds = mpltools.get_axes_bounds(fig)
#      91         margin = go.layout.Margin(
#      92             l=int(self.mpl_x_bounds[0] * self.plotly_fig["layout"]["width"]),
#
# /anaconda3/lib/python3.7/site-packages/plotly/matplotlylib/mpltools.py in get_axes_bounds(fig)
#     263         y_min.append(bounds[1])
#     264         y_max.append(bounds[1] + bounds[3])
# --> 265     x_min, y_min, x_max, y_max = min(x_min), min(y_min), max(x_max), max(y_max)
#     266     return (x_min, x_max), (y_min, y_max)
#     267
#
# ValueError: min() arg is an empty sequence

# %%
pip install wandb --upgrade

# %% [markdown]
# ## Fix the issue way one

# %%
# %%capture output
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import wandb

wandb.init(project = 'issue', config={"gamma":0.1, "C":1.0, "test_size": 0.3, "seed": 0})

iris = datasets.load_iris()

X = iris.data[:, [2, 3]]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=wandb.config.test_size, random_state=wandb.config.seed)

sc = StandardScaler()
sc.fit(X_train)

X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

svm = SVC(kernel='rbf', random_state=wandb.config.seed, gamma=wandb.config.gamma, C=wandb.config.C)
svm.fit(X_train_std, y_train)

wandb.log({"Train Accuracy": svm.score(X_train_std, y_train), 
           "Test Accuracy": svm.score(X_test_std, y_test)})

def plot_data():
    from matplotlib.colors import ListedColormap
    import matplotlib.pyplot as plt

    markers = ('s', 'x', 'o')
    colors = ('red', 'blue', 'lightgreen')
    cmap = ListedColormap(colors[:len(np.unique(y_test))])
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
               c=cmap(idx), marker=markers[idx], label=cl)

    wandb.log({"Data": wandb.Image(plt)})
    
    wandb.log({"Same data": wandb.Image(plt)})

plot_data()

# %% [markdown]
# ## Fix the issue way two

# %%
# %%capture output
import numpy as np
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import wandb

wandb.init(project = 'issue', config={"gamma":0.1, "C":1.0, "test_size": 0.3, "seed": 0})

iris = datasets.load_iris()

X = iris.data[:, [2, 3]]
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=wandb.config.test_size, random_state=wandb.config.seed)

sc = StandardScaler()
sc.fit(X_train)

X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

svm = SVC(kernel='rbf', random_state=wandb.config.seed, gamma=wandb.config.gamma, C=wandb.config.C)
svm.fit(X_train_std, y_train)

wandb.log({"Train Accuracy": svm.score(X_train_std, y_train), 
           "Test Accuracy": svm.score(X_test_std, y_test)})

def plot_data():
    from matplotlib.colors import ListedColormap
    import matplotlib.pyplot as plt

    markers = ('s', 'x', 'o')
    colors = ('red', 'blue', 'lightgreen')
    cmap = ListedColormap(colors[:len(np.unique(y_test))])
    plt.figure(0)
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
               c=cmap(idx), marker=markers[idx], label=cl)

    wandb.log({"Data": plt.figure(0)})
    #this is happening because when you log the matplotlib object we close the figure, 
    # so you can't log the same object twice. To fix this, you can create multiple instances of 
    # plot.figure() and pass those in to wandb.log
    
    plt.figure(1)
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
               c=cmap(idx), marker=markers[idx], label=cl)
    
    wandb.log({"Same data": plt.figure(1)})

plot_data()
